# %%
import openai 
print("version =",openai.__version__)

from openai import OpenAI
api_key_str = "sk-0g56v3qYextZ5b1JcxksAO6ZxJ3ZP7Y9uEVT4nEc6HRkVYde"
client = OpenAI(
    api_key=api_key_str,
    base_url="https://api.moonshot.cn/v1",
)

prompt_str = "你是文本分析专家，请理解给定的文本，判断文本的情感类别，可选的类别范围是：积极和消极。"
given_text = "这个看上去还可以，但其实我不喜欢。。"
completion = client.chat.completions.create(
  model="moonshot-v1-8k",
  messages=[
    {"role": "system", "content": prompt_str},
    {"role": "user", "content": "给定文本：" + given_text}
  ],
  temperature=0.3,
)
 
print(completion.choices[0].message.content)
from sklearn.metrics import accuracy_score, recall_score, f1_score  

def read_file(file_path):  
    true_labels = []  
    texts = []  
    with open(file_path, 'r', encoding='utf-8') as file:  
        for line in file:  
            text = line.strip().split(',', 1)  
            true_labels.append(text[0])  
            texts.append(text[1])  
    return true_labels, texts
    
# test_text= '我好开心啊，非常非常非常高兴！今天我得了一百分，我很兴奋开心，愉快，开心'
labels, texts = read_file("comments-1k.txt")
# print(senti.sentiment_count(test_text))
# print(senti.sentiment_calculate(test_text))
labels.pop(0)
texts.pop(0)
# print(labels, texts)

pre_labels = []
for i in range(len(labels)):
    result = senti.sentiment_calculate(texts[i])
    pos = result['pos']
    neg = result['neg']
    if pos > neg:
        pre = 1
    else: 
        pre = 0
    pre_labels.append(pre)
    labels[i] = int(labels[i])
    
accuracy = accuracy_score(labels, pre_labels)  
recall = recall_score(labels, pre_labels, pos_label=1)  
f1 = f1_score(labels, pre_labels, pos_label=1)  
  
print(f"Accuracy: {accuracy:.2f}")  
print(f"Recall: {recall:.2f}")  
print(f"F1 Score: {f1:.2f}")
# Out:
# version = 1.30.1
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 13
#      11 prompt_str = "你是文本分析专家，请理解给定的文本，判断文本的情感类别，可选的类别范围是：积极和消极。"
#      12 given_text = "这个看上去还可以，但其实我不喜欢。。"
# ---> 13 completion = client.chat.completions.create(
#      14   model="moonshot-v1-8k",
#      15   messages=[
#      16     {"role": "system", "content": prompt_str},
#      17     {"role": "user", "content": "给定文本：" + given_text}
#      18   ],
#      19   temperature=0.3,
#      20 )
#      22 print(completion.choices[0].message.content)
#      23 from sklearn.metrics import accuracy_score, recall_score, f1_score
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
# ...
